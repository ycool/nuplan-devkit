# %% [markdown]
# ![](https://www.nuplan.org/static/media/nuPlan_final.3fde7586.png)

# %% [markdown]
# ### Contents
#
# 1. [Introduction to nuPlan](#introduction)
# 2. [Training an ML planner](#training)
# 3. [Simulating a planner](#simulation)
# 4. [Visualizing metrics and scenarios](#dashboard)

# %%
from tutorials.utils.tutorial_utils import setup_notebook

setup_notebook()

# %%
# !echo $PYTHONPATH
# Out:
# :/home/hujiangtao/github/nuplan-devkit:/home/jt/miniconda3/envs/nuplan/lib/python3.9/site-packages

# %%
import array
import torch
a = array.array('i', [1, 2, 3])
t = torch.frombuffer(a, dtype=torch.int32)
t
# Out:
# tensor([1, 2, 3], dtype=torch.int32)

# %%
#!pwd 
import torch
torch.__version__
# Out:
# '2.0.1+cu117'

# %%
from torchmetrics.utilities.data import get_num_classes as _get_num_classes
# Out:
# /home/hujiangtao/miniconda3/envs/nuplan3/lib/python3.9/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: 'libc10_hip.so: cannot open shared object file: No such file or directory'If you don't plan on using image functionality from `torchvision.io`, you can ignore this warning. Otherwise, there might be something wrong with your environment. Did you have `libjpeg` or `libpng` installed before building `torchvision` from source?
#   warn(

# %% [markdown]
# # Introduction to nuPlan <a name="introduction"></a>

# %% [markdown]
# Welcome to nuPlan! This notebook will explore the nuPlan simulation framework, training platform as well as the nuBoard metrics/scenarios visualization dashboard.

# %% [markdown]
# ## What is nuPlan
#
# nuPlan is the world’s first closed-loop ML-based planning benchmark for autonomous driving.
#
# It provides a high quality dataset with 1500h of human driving data from 4 cities across the US and Asia with widely varying traffic patterns (Boston, Pittsburgh, Las Vegas and Singapore). In addition, it provides a closed-loop simulation framework with reactive agents, a training platform as well as a large set of both general and scenario-specific planning metrics.
#
# ![](https://www.nuscenes.org/static/media/framework_steps.2d4642df.png)

# %% [markdown]
# ## Training & simulation framework
#
# The nuPlan training and simulation framework aims to:
# * create a simulation pipeline to evaluate a planner on large dataset with various scenarios
# * score planner performance with common and scenario-dependent metrics
# * compare planners based on measured metrics and provide intuitive visualizations
# * train planners with the provided framework to allow quick implementation and iteration
# * support closed-loop simulation and training
#
# <br />
#
# ![](https://www.nuplan.org/static/media/planning_framework.ca3c2969.png)

# %% [markdown]
# ## Scenarios in nuPlan
#
# nuPlan aims to capture challenging yet representative scenarios from real-world encounters. This enables the benchmarking of planning systems both in expert imitation (open-loop) and reactive planning (closed-loop) settings.
#
# These scenarios includes:
# * highly interactive scenes with traffic participants (e.g. tailgating, high-velocity overtakes, double parked cars, jaywalking)
# * various ego behaviors (e.g. vehicle following, yielding, lane merging) and dynamics (e.g. mixed speed profiles, abrupt braking, speed bumps, high jerk maneuvers)
# * scene layouts of varied complexity (e.g. pudos, traffic/stop controlled intersections, unprotected turns) and temporary zones (e.g. construction areas)
#
# The dataset is automatically tagged with scenario labels based on certain primitive attributes.
# These scenario tags can then be used to extract representative metrics for the planner's evaluation.
#
# Example mined scenarios in nuPlan:
#
# | | | |
# | :-: | :-: | :-: |
# | Unprotected cross turn | Dense vehicle interactions | Jaywalker in front |
# | ![](https://www.nuscenes.org/static/media/unprotected-cross.51feef7e.webp) | ![](https://www.nuscenes.org/static/media/dense-interactions.16de47ec.webp) | ![](https://www.nuscenes.org/static/media/jaywalker.03083823.webp) |
# | Lane change | Ego at pickup/dropoff area | Ego following vehicle |
# | ![](https://www.nuscenes.org/static/media/lane-change.54bfca1c.webp) | ![](https://www.nuscenes.org/static/media/pickup-dropoff.4dd1c418.webp) | ![](https://www.nuscenes.org/static/media/following-vehicle.4cacd559.webp) |

# %% [markdown]
# ## Database
#
# Download a database for training/simulation from [here](https://nuplan.org/nuplan#download).
#
# | Database | Size | Duration | Num Logs | Cities | Num Scenarios | Sensor Data | Description |
# | :-- | :-- | :-- | :-- | :-- | :-- | :-- | :-- |
# | nuplan_v1.1_mini (recommended) | 13GB | 7h | 64 | Las Vegas, Boston, Pittsburgh, Singapore | 67 | N/A | The mini split used for prototyping and testing |
# | nuplan_v1.1 | 1.8TB | 1282h | 15910 | Las Vegas, Boston, Pittsburgh, Singapore | 73 | N/A | The full dataset for training and evaluation|

# %% [markdown]
# ## Setup
#
# To be able to access all resources within this notebook, make sure Jupyter is launched at the root of this repo. The path of the notebook should be `/notebook/<repo_root>`.

# %%
# (Optional) Increase notebook width for all embedded cells to display properly
from IPython.core.display import display, HTML
display(HTML("<style>.output_result { max-width:100% !important; }</style>"))
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# /tmp/ipykernel_20809/4180358289.py:2: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML
# <style>.output_result { max-width:100% !important; }</style>
# <style>.container { width:100% !important; }</style>

# %%
# Useful imports
import os
from pathlib import Path
import tempfile

import hydra

# %% [markdown]
# # Training an ML planner <a name="training"></a>

# %% [markdown]
# ## Imitation learning
# In the following section we will train an ML planning policy with the aim estimate the ego's future trajectory and control the vehicle.
#
# The policy is learned through imitation learning, a supervised learning approach in which - in the context of autonomous driving - the behavior of an expert human driver is used as a target signal to supervise the model.
#
# ## Model features & targets
# A planning policy consumes a set of episodic observations and encodes them through a deep neural network to regress a future trajectory.
#
# The observations can be historic or present ego and agent poses as well as static/dynamic map information across different map layers.<br />
# These signals can be encoded through various representations, such as raster or vector format for the map signal, each with their pros and cons for each model flavor.
#
# Using these input features the model predicts a discretized future trajectory across a fixed time horizon.<br />
# The trajectory consists of a set of discrete future states (position, heading and velocity) sampled at fixed intervals which express the likelihood of the vehicle being at that state in the future.<br />
# For example, a predicted trajectory may consist of 10 future poses sampled at intervals of 0.5s across a 5s horizon.
#
# ## Learning objectives
# The policy is trained to maximize a set of aggregated objectives such as imitation, collision avoidance, traffic rule violation etc.<br />
# Imitation is the core training objective which indicates how close the predicted trajectory is to the expert ground truth and penalizes model predictions that deviate in space and time from the demonstration.

# %% [markdown]
# ## Training parameters

# %% [markdown]
# The following parameter categories define the training protocol which includes the model, metrics, objectives etc.
#
# A working example composition of these parameters can be found in the next section.
#
# ---
#
# ### ML models
#
# Change the training model with `model=X` where `X` is a config yaml defined in the table below.
#
# | Model | Description | Config |
# | --- | --- | --- |
# | Raster model (CNN) | Raster-based model that uses a CNN backbone to encode ego, agent and map information as raster layers<br />Any (pretrained) backbone from the TIMM library can be used (e.g. ResNet50, EfficientNetB3) | `raster_model` |
# | Vector model (LaneGCN) | Vector-based model that uses a series of MLPs to encode ego and agent signals, a lane graph to encode vector-map elements and a fusion network to capture lane & agent intra/inter-interactions through attention layers<br />Implementation of LaneGCN paper ("Learning Lane Graph Representations for Motion Forecasting") | `vector_model` |
# | Simple vector model | Toy vector-based model that consumes ego, agent and lane signals through a series of MLPs | `simple_vector_model` |
#
# <br />
#
# ### Training objectives
#
# Change the training objectives with `objective=[X, ...]` where `X` is a config yaml defined in the table below.
#
# | Objective | Description | Config |
# | --- | --- | --- |
# | Imitation objective | Penalizes the predicted trajectory that deviates from the expert demonstration | `imitation_objective` |
#
# <br />
#
# ### Training metrics
#
# Change the training objectives with `training_metric=[X, ...]` where `X` is a config yaml defined in the table below.
#
# | Metric | Description | Config |
# | --- | --- | --- |
# | Average displacement error | RMSE translation error across full predicted trajectory | `avg_displacement_error` |
# | Average heading error | RMSE heading error across full predicted trajectory | `avg_heading_error` |
# | Final displacement error | L2 error of predicted trajectory's final pose translation | `final_displacement_error` |
# | Final heading error | L2 error of predicted trajectory's final pose heading | `final_heading_error` |

# %% [markdown]
# ## Prepare the training config

# %%
# Location of path with all training configs
CONFIG_PATH = '../nuplan/planning/script/config/training'
CONFIG_NAME = 'default_training'

# Create a temporary directory to store the cache and experiment artifacts
SAVE_DIR = Path(tempfile.gettempdir()) / 'tutorial_nuplan_framework'  # optionally replace with persistent dir
EXPERIMENT = 'training_raster_experiment'
JOB_NAME = 'train_default_raster'
LOG_DIR = SAVE_DIR / EXPERIMENT / JOB_NAME

# Initialize configuration management system
hydra.core.global_hydra.GlobalHydra.instance().clear()
hydra.initialize(config_path=CONFIG_PATH)

# Compose the configuration
cfg = hydra.compose(config_name=CONFIG_NAME, overrides=[
    f'group={str(SAVE_DIR)}',
    f'cache.cache_path={str(SAVE_DIR)}/cache',
    f'experiment_name={EXPERIMENT}',
    f'job_name={JOB_NAME}',
    'py_func=train',
    '+training=training_raster_model',  # raster model that consumes ego, agents and map raster layers and regresses the ego's trajectory
    'scenario_builder=nuplan_mini',  # use nuplan mini database
    'scenario_filter.limit_total_scenarios=500',  # Choose 500 scenarios to train with
    'lightning.trainer.params.accelerator=ddp_spawn',  # ddp is not allowed in interactive environment, using ddp_spawn instead - this can bottleneck the data pipeline, it is recommended to run training outside the notebook
    'lightning.trainer.params.max_epochs=10',
    'data_loader.params.batch_size=8',
    'data_loader.params.num_workers=8',
])

# %%
# !pwd
print(LOG_DIR)
# Out:
# /tmp/tutorial_nuplan_framework/training_raster_experiment/train_default_raster

# %% [markdown]
# ## Launch tensorboard for visualizing training artifacts

# %%
# %load_ext tensorboard
# %tensorboard --logdir {str(LOG_DIR)}
# Out:
#       <iframe id="tensorboard-frame-c1ec327cc5d6f6ba" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-c1ec327cc5d6f6ba");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %% [markdown]
# ## Launch training (within the notebook)

# %%
from nuplan.planning.script.run_training import main as main_train

# Run the training loop, optionally inspect training artifacts through tensorboard (above cell)
main_train(cfg)
# Out:
# Global seed set to 0
# 2023-08-28 10:31:28,322 INFO {/home/hujiangtao/github/nuplan-devkit/nuplan/planning/script/builders/folder_builder.py:20}  Building experiment folders...
# 2023-08-28 10:31:28,322 INFO {/home/hujiangtao/github/nuplan-devkit/nuplan/planning/script/builders/folder_builder.py:22}  Experimental folder: /tmp/tutorial_nuplan_framework/training_raster_experiment/train_default_raster/2023.08.28.10.31.28
# 2023-08-28 10:31:28,322 INFO {/home/hujiangtao/github/nuplan-devkit/nuplan/planning/script/builders/worker_pool_builder.py:19}  Building WorkerPool...
# 2023-08-28 10:31:28,331 INFO {/home/hujiangtao/github/nuplan-devkit/nuplan/planning/utils/multithreading/worker_ray.py:78}  Starting ray local!
# 2023-08-28 10:31:30,175	INFO worker.py:1621 -- Started a local Ray instance.
# 2023-08-28 10:31:30,886 INFO {/home/hujiangtao/github/nuplan-devkit/nuplan/planning/utils/multithreading/worker_pool.py:101}  Worker: RayDistributed
# 2023-08-28 10:31:30,886 INFO {/home/hujiangtao/github/nuplan-devkit/nuplan/planning/utils/multithreading/worker_pool.py:102}  Number of nodes: 1
# Number of CPUs per node: 32
# Number of GPUs per node: 1
# Number of threads across all nodes: 32
# 2023-08-28 10:31:30,887 INFO {/home/hujiangtao/github/nuplan-devkit/nuplan/planning/script/builders/worker_pool_builder.py:27}  Building WorkerPool...DONE!
# 2023-08-28 10:31:30,887 INFO {/home/hujiangtao/github/nuplan-devkit/nuplan/planning/training/experiments/training.py:41}  Building training engine...
# 2023-08-28 10:31:30,887 INFO {/home/hujiangtao/github/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2023-08-28 10:31:31,374 INFO {/home/hujiangtao/miniconda3/envs/nuplan3/lib/python3.9/site-packages/timm/models/_builder.py:182}  Loading pretrained weights from Hugging Face hub (timm/resnet50.a1_in1k)
# Downloading model.safetensors:   0%|          | 0.00/102M [00:00<?, ?B/s]
# 2023-08-28 10:31:39,891 INFO {/home/hujiangtao/miniconda3/envs/nuplan3/lib/python3.9/site-packages/timm/models/_hub.py:180}  [timm/resnet50.a1_in1k] Safe alternative available for 'pytorch_model.bin' (as 'model.safetensors'). Loading weights using safetensors.
# 2023-08-28 10:31:39,950 INFO {/home/hujiangtao/miniconda3/envs/nuplan3/lib/python3.9/site-packages/timm/models/_builder.py:206}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2023-08-28 10:31:39,999 INFO {/home/hujiangtao/github/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2023-08-28 10:31:40,000 INFO {/home/hujiangtao/github/nuplan-devkit/nuplan/planning/script/builders/splitter_builder.py:18}  Building Splitter...
# 2023-08-28 10:31:40,414 INFO {/home/hujiangtao/github/nuplan-devkit/nuplan/planning/script/builders/splitter_builder.py:21}  Building Splitter...DONE!
# 2023-08-28 10:31:40,414 INFO {/home/hujiangtao/github/nuplan-devkit/nuplan/planning/script/builders/scenario_building_builder.py:18}  Building AbstractScenarioBuilder...
# 2023-08-28 10:31:40,420 INFO {/home/hujiangtao/github/nuplan-devkit/nuplan/planning/scenario_builder/nuplan_db/nuplan_scenario_builder.py:74}  === data root: /home/hujiangtao/nuplan/dataset/nuplan-v1.1/splits/mini
# 2023-08-28 10:31:40,421 INFO {/home/hujiangtao/github/nuplan-devkit/nuplan/planning/scenario_builder/nuplan_db/nuplan_scenario_builder.py:76}  === db_files: ['/home/hujiangtao/nuplan/dataset/nuplan-v1.1/splits/mini/2021.05.12.22.00.38_veh-35_01008_01518.db', '/home/hujiangtao/nuplan/dataset/nuplan-v1.1/splits/mini/2021.05.12.22.28.35_veh-35_00620_01164.db', '/home/hujiangtao/nuplan/dataset/nuplan-v1.1/splits/mini/2021.05.12.23.36.44_veh-35_00152_00504.db', '/home/hujiangtao/nuplan/dataset/nuplan-v1.1/splits/mini/2021.05.12.23.36.44_veh-35_01133_01535.db', '/home/hujiangtao/nuplan/dataset/nuplan-v1.1/splits/mini/2021.05.12.23.36.44_veh-35_02035_02387.db', '/home/hujiangtao/nuplan/dataset/nuplan-v1.1/splits/mini/2021.05.25.14.16.10_veh-35_01690_02183.db', '/home/hujiangtao/nuplan/dataset/nuplan-v1.1/splits/mini/2021.06.03.12.02.06_veh-35_00233_00609.db', '/home/hujiangtao/nuplan/dataset/nuplan-v1.1/splits/mini/2021.06.03.13.55.17_veh-35_00073_00426.db', '/home/hujiangtao/nuplan/dataset/nuplan-v1.1/splits/mini/2021.06.07.12.54.00_veh-35_01843_02314.db', '/home/hujiangtao/nuplan/dataset/nuplan-v1.1/splits/mini/2021.06.07.18.53.26_veh-26_00005_00427.db', '/home/hujiangtao/nuplan/dataset/nuplan-v1.1/splits/mini/2021.06.08.12.54.54_veh-26_04262_04732.db', '/home/hujiangtao/nuplan/dataset/nuplan-v1.1/splits/mini/2021.06.08.14.35.24_veh-26_02555_03004.db', '/home/hujiangtao/nuplan/dataset/nuplan-v1.1/splits/mini/2021.06.08.16.31.33_veh-38_01589_02072.db', '/home/hujiangtao/nuplan/dataset/nuplan-v1.1/splits/mini/2021.06.09.11.54.15_veh-12_04366_04810.db', '/home/hujiangtao/nuplan/dataset/nuplan-v1.1/splits/mini/2021.06.09.12.39.51_veh-26_01943_02303.db', '/home/hujiangtao/nuplan/dataset/nuplan-v1.1/splits/mini/2021.06.09.12.39.51_veh-26_05620_06003.db', '/home/hujiangtao/nuplan/dataset/nuplan-v1.1/splits/mini/2021.06.09.14.03.17_veh-12_02584_02970.db', '/home/hujiangtao/nuplan/dataset/nuplan-v1.1/splits/mini/2021.06.09.14.58.55_veh-35_01095_01484.db', '/home/hujiangtao/nuplan/dataset/nuplan-v1.1/splits/mini/2021.06.09.14.58.55_veh-35_01894_02311.db', '/home/hujiangtao/nuplan/dataset/nuplan-v1.1/splits/mini/2021.06.09.17.23.18_veh-38_00773_01140.db', '/home/hujiangtao/nuplan/dataset/nuplan-v1.1/splits/mini/2021.06.09.17.23.18_veh-38_02526_03027.db', '/home/hujiangtao/nuplan/dataset/nuplan-v1.1/splits/mini/2021.06.09.17.37.09_veh-12_00404_00864.db', '/home/hujiangtao/nuplan/dataset/nuplan-v1.1/splits/mini/2021.06.14.16.32.09_veh-35_05038_05402.db', '/home/hujiangtao/nuplan/dataset/nuplan-v1.1/splits/mini/2021.06.14.16.48.02_veh-12_04057_04438.db', '/home/hujiangtao/nuplan/dataset/nuplan-v1.1/splits/mini/2021.06.14.16.48.02_veh-12_04978_05337.db', '/home/hujiangtao/nuplan/dataset/nuplan-v1.1/splits/mini/2021.06.14.17.26.26_veh-38_04544_04920.db', '/home/hujiangtao/nuplan/dataset/nuplan-v1.1/splits/mini/2021.06.14.18.33.41_veh-35_03901_04264.db', '/home/hujiangtao/nuplan/dataset/nuplan-v1.1/splits/mini/2021.06.14.18.42.45_veh-12_03445_03902.db', '/home/hujiangtao/nuplan/dataset/nuplan-v1.1/splits/mini/2021.06.14.19.22.11_veh-38_01480_01860.db', '/home/hujiangtao/nuplan/dataset/nuplan-v1.1/splits/mini/2021.06.23.15.56.12_veh-16_00839_01285.db', '/home/hujiangtao/nuplan/dataset/nuplan-v1.1/splits/mini/2021.06.23.16.54.19_veh-35_00808_01256.db', '/home/hujiangtao/nuplan/dataset/nuplan-v1.1/splits/mini/2021.06.23.17.31.36_veh-16_00016_00377.db', '/home/hujiangtao/nuplan/dataset/nuplan-v1.1/splits/mini/2021.06.23.20.43.31_veh-16_03607_04007.db', '/home/hujiangtao/nuplan/dataset/nuplan-v1.1/splits/mini/2021.06.28.15.02.02_veh-38_02398_02848.db', '/home/hujiangtao/nuplan/dataset/nuplan-v1.1/splits/mini/2021.06.28.16.29.11_veh-38_01415_01821.db', '/home/hujiangtao/nuplan/dataset/nuplan-v1.1/splits/mini/2021.06.28.16.29.11_veh-38_03263_03766.db', '/home/hujiangtao/nuplan/dataset/nuplan-v1.1/splits/mini/2021.06.28.16.57.59_veh-26_00016_00484.db', '/home/hujiangtao/nuplan/dataset/nuplan-v1.1/splits/mini/2021.07.09.17.06.37_veh-35_00258_00748.db', '/ho ...
# 2023-08-28 10:31:40,421 INFO {/home/hujiangtao/github/nuplan-devkit/nuplan/planning/script/builders/scenario_building_builder.py:21}  Building AbstractScenarioBuilder...DONE!
# 2023-08-28 10:31:40,421 INFO {/home/hujiangtao/github/nuplan-devkit/nuplan/planning/script/builders/scenario_filter_builder.py:35}  Building ScenarioFilter...
# 2023-08-28 10:31:40,421 INFO {/home/hujiangtao/github/nuplan-devkit/nuplan/planning/script/builders/scenario_filter_builder.py:44}  Building ScenarioFilter...DONE!
# Ray objects: 100%|██████████████████████████████████████████████████| 32/32 [00:02<00:00, 12.22it/s]
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# Using native 16bit precision.
# Global seed set to 0
# initializing ddp: GLOBAL_RANK: 0, MEMBER: 1/1
# ----------------------------------------------------------------------------------------------------
# distributed_backend=nccl
# All DDP processes registered. Starting ddp with 1 processes
# ----------------------------------------------------------------------------------------------------
# 2023-08-28 10:31:43,185 INFO {/home/hujiangtao/github/nuplan-devkit/nuplan/planning/script/builders/scenario_builder.py:172}  Extracted 500 scenarios for training
# 2023-08-28 10:31:43,185 INFO {/home/hujiangtao/github/nuplan-devkit/nuplan/planning/training/experiments/training.py:52}  Updating configs based on ddp_spawn strategy is currently not supported. Optimizer and LR Scheduler configs will not be updated.
# 2023-08-28 10:31:43,187 INFO {/home/hujiangtao/github/nuplan-devkit/nuplan/planning/script/builders/training_callback_builder.py:19}  Building callbacks...
# 2023-08-28 10:31:43,200 INFO {/home/hujiangtao/github/nuplan-devkit/nuplan/planning/script/builders/training_callback_builder.py:37}  Building callbacks...DONE!
# 2023-08-28 10:31:43,203 INFO {/home/hujiangtao/github/nuplan-devkit/nuplan/planning/script/run_training.py:62}  Starting training...
# 2023-08-28 10:31:43,237 INFO {/home/hujiangtao/miniconda3/envs/nuplan3/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:442}  Added key: store_based_barrier_key:1 to store for rank: 0
# 2023-08-28 10:31:43,237 INFO {/home/hujiangtao/miniconda3/envs/nuplan3/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:476}  Rank 0: Completed store-based barrier for key:store_based_barrier_key:1 with 1 nodes.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name  | Type        | Params
# --------------------------------------
# 0 | model | RasterModel | 23.6 M
# --------------------------------------
# 23.6 M    Trainable params
# 0         Non-trainable params
# 23.6 M    Total params
# 94.438    Total estimated model params size (MB)
# 2023-08-28 10:31:45,452 INFO {/home/hujiangtao/github/nuplan-devkit/nuplan/planning/training/data_loader/datamodule.py:47}  Number of samples in train set: 328
# 2023-08-28 10:31:45,453 INFO {/home/hujiangtao/github/nuplan-devkit/nuplan/planning/training/data_loader/datamodule.py:47}  Number of samples in validation set: 80
# 2023-08-28 10:31:45,455 INFO {/home/hujiangtao/github/nuplan-devkit/nuplan/planning/training/modeling/lightning_module_wrapper.py:196}  Using optimizer: torch.optim.Adam
# 2023-08-28 10:31:45,455 INFO {/home/hujiangtao/github/nuplan-devkit/nuplan/planning/script/builders/lr_scheduler_builder.py:52}  Not using any lr_schedulers.
# /home/hujiangtao/miniconda3/envs/nuplan3/lib/python3.9/site-packages/pytorch_lightning/trainer/data_loading.py:73: UserWarning: num_workers>0, persistent_workers=False, and accelerator=ddp_spawn may result in data loading bottlenecks. Consider setting persistent_workers=True (this is a limitation of Python .spawn() and PyTorch)
#   rank_zero_warn(
# /home/hujiangtao/miniconda3/envs/nuplan3/lib/python3.9/site-packages/pytorch_lightning/callbacks/lr_monitor.py:97: RuntimeWarning: You are using `LearningRateMonitor` callback with models that have no learning rate schedulers. Please see documentation for `configure_optimizers` method.
#   rank_zero_warn(
# Training: 0it [00:00, ?it/s]
# 2023-08-28 10:31:50,259 INFO {/home/hujiangtao/miniconda3/envs/nuplan3/lib/python3.9/site-packages/torch/nn/parallel/distributed.py:1140}  Reducer buckets have been rebuilt in this iteration.
# /home/hujiangtao/miniconda3/envs/nuplan3/lib/python3.9/site-packages/pytorch_lightning/trainer/callback_hook.py:100: LightningDeprecationWarning: The signature of `Callback.on_train_epoch_end` has changed in v1.3. `outputs` parameter has been removed. Support for the old signature will be removed in v1.5
#   warning_cache.deprecation(
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]

# %% [markdown]
# ## Launch training (command line - alternative)

# %% [markdown]
# A training experiment with the above same parameters can be launched alternatively with:
# ```
# $ python nuplan/planning/script/run_training.py \
#     experiment_name=raster_experiment \
#     py_func=train \
#     +training=training_raster_model \
#     scenario_builder=nuplan_mini \
#     scenario_filter.limit_total_scenarios=500 \
#     lightning.trainer.params.max_epochs=10 \
#     data_loader.params.batch_size=8 \
#     data_loader.params.num_workers=8
# ```

# %% [markdown]
# # Simulating a planner <a name="simulation"></a>

# %% [markdown]
# ## Open-loop simulation
# Open-loop simulation aims to evaluate the policy's capabilities to imitate the expert driver's behavior.<br />
# This is essentially done through log replay as the policy's predictions do not affect the state of the simulation.
#
# As the policy is not in full control of the vehicle, this type of simulation can only provide a high-level performance overview.
#
# ## Closed-loop simulation
# Conversely, in closed-loop simulation the policy's actions alter the state of the simulation which tries to closely approximate the real-world system.
#
# The simulation's feedback loop enables a more in-depth evaluation of the policy as compounding errors can cause future observations to significantly diverge from the ground truth.<br />
# This is important in measuring distribution shifts introduced due to lack of variance in training examples through pure imitation learning.
#
# Closed-loop simulation is further divided into two categories:
# * ego closed-loop simulation with agents replayed from log (open-loop, non reactive)
# * ego closed-loop simulation with agents controlled by a rule-based or learned policy (closed-loop, reactive)
#
# ## Measuring success
# Measuring the success of a planning task and comparing various planning policies is a complicated effort that involves defining metrics across different vertical dimensions and scenario categories.<br />
# These metrics include indicators such as vehicle dynamics, traffic rule violations, expert imitation, navigation success etc.<br />
# Overall, they aim to capture the policy's ability to control the autonomous vehicle safely yet efficiently without compromising the passenger's comfort.

# %% [markdown]
# ## Simulation parameters

# %% [markdown]
# ### Planners
#
# Change the planner model with `planner=X` where `X` is a config yaml defined in the table below.
#
# | Planner | Description | Config |
# | --- | --- | --- |
# | Simple Planner | Naive planner that only plans a straight path | `simple_planner` |
# | ML Planner | Learning-based planner trained using the nuPlan training framework (see previous section) | `ml_planner` |

# %% [markdown]
# ## Prepare the simulation config

# %%
# Location of path with all simulation configs
CONFIG_PATH = '../nuplan/planning/script/config/simulation'
CONFIG_NAME = 'default_simulation'

# Select the planner and simulation challenge
PLANNER = 'simple_planner'  # [simple_planner, ml_planner]
CHALLENGE = 'open_loop_boxes'  # [open_loop_boxes, closed_loop_nonreactive_agents, closed_loop_reactive_agents]
DATASET_PARAMS = [
    'scenario_builder=nuplan_mini',  # use nuplan mini database
    'scenario_filter=all_scenarios',  # initially select all scenarios in the database
    'scenario_filter.scenario_types=[near_multiple_vehicles, on_pickup_dropoff, starting_unprotected_cross_turn, high_magnitude_jerk]',  # select scenario types
    'scenario_filter.num_scenarios_per_type=10',  # use 10 scenarios per scenario type
]

# Name of the experiment
EXPERIMENT = 'simulation_simple_experiment'

# Initialize configuration management system
hydra.core.global_hydra.GlobalHydra.instance().clear()  # reinitialize hydra if already initialized
hydra.initialize(config_path=CONFIG_PATH)

# Compose the configuration
cfg = hydra.compose(config_name=CONFIG_NAME, overrides=[
    f'experiment_name={EXPERIMENT}',
    f'group={SAVE_DIR}',
    f'planner={PLANNER}',
    f'+simulation={CHALLENGE}',
    *DATASET_PARAMS,
])

# %% [markdown]
# ## Launch simulation (within the notebook)

# %%
from nuplan.planning.script.run_simulation import main as main_simulation

# Run the simulation loop (real-time visualization not yet supported, see next section for visualization)
main_simulation(cfg)

# Simple simulation folder for visualization in nuBoard
simple_simulation_folder = cfg.output_dir
# Out:
# Global seed set to 0
# 2023-08-28 10:37:01,115 INFO {/home/hujiangtao/github/nuplan-devkit/nuplan/planning/script/builders/main_callback_builder.py:20}  Building MultiMainCallback...
# 2023-08-28 10:37:01,160 INFO {/home/hujiangtao/github/nuplan-devkit/nuplan/planning/script/builders/main_callback_builder.py:35}  Building MultiMainCallback: 4...DONE!
# 2023-08-28 10:37:01,244 INFO {/home/hujiangtao/github/nuplan-devkit/nuplan/planning/script/builders/worker_pool_builder.py:19}  Building WorkerPool...
# 2023-08-28 10:37:01,244 WARNING {/home/hujiangtao/github/nuplan-devkit/nuplan/planning/utils/multithreading/worker_ray.py:135}  Ray is running, we will shut it down before starting again!
# 2023-08-28 10:37:02,936 INFO {/home/hujiangtao/github/nuplan-devkit/nuplan/planning/utils/multithreading/worker_ray.py:78}  Starting ray local!
# 2023-08-28 10:37:05,288	INFO worker.py:1621 -- Started a local Ray instance.
# 2023-08-28 10:37:05,921 INFO {/home/hujiangtao/github/nuplan-devkit/nuplan/planning/utils/multithreading/worker_pool.py:101}  Worker: RayDistributed
# 2023-08-28 10:37:05,921 INFO {/home/hujiangtao/github/nuplan-devkit/nuplan/planning/utils/multithreading/worker_pool.py:102}  Number of nodes: 1
# Number of CPUs per node: 32
# Number of GPUs per node: 1
# Number of threads across all nodes: 32
# 2023-08-28 10:37:05,921 INFO {/home/hujiangtao/github/nuplan-devkit/nuplan/planning/script/builders/worker_pool_builder.py:27}  Building WorkerPool...DONE!
# 2023-08-28 10:37:05,921 INFO {/home/hujiangtao/github/nuplan-devkit/nuplan/planning/script/builders/folder_builder.py:32}  Building experiment folders...
# 2023-08-28 10:37:05,921 INFO {/home/hujiangtao/github/nuplan-devkit/nuplan/planning/script/builders/folder_builder.py:35}
#
# 	Folder where all results are stored: /tmp/tutorial_nuplan_framework/simulation_simple_experiment/open_loop_boxes/2023.08.28.10.37.01
#
# 2023-08-28 10:37:05,922 INFO {/home/hujiangtao/github/nuplan-devkit/nuplan/planning/script/builders/folder_builder.py:70}  Building experiment folders...DONE!
# 2023-08-28 10:37:05,922 INFO {/home/hujiangtao/github/nuplan-devkit/nuplan/planning/script/builders/simulation_callback_builder.py:52}  Building AbstractCallback...
# 2023-08-28 10:37:05,923 INFO {/home/hujiangtao/github/nuplan-devkit/nuplan/planning/script/builders/simulation_callback_builder.py:68}  Building AbstractCallback: 0...DONE!
# 2023-08-28 10:37:05,923 INFO {/home/hujiangtao/github/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:47}  Building simulations...
# 2023-08-28 10:37:05,923 INFO {/home/hujiangtao/github/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:53}  Extracting scenarios...
# 2023-08-28 10:37:05,923 INFO {/home/hujiangtao/github/nuplan-devkit/nuplan/common/utils/distributed_scenario_filter.py:83}  Building Scenarios in mode DistributedMode.SINGLE_NODE
# 2023-08-28 10:37:05,923 INFO {/home/hujiangtao/github/nuplan-devkit/nuplan/planning/script/builders/scenario_building_builder.py:18}  Building AbstractScenarioBuilder...
# 2023-08-28 10:37:05,933 INFO {/home/hujiangtao/github/nuplan-devkit/nuplan/planning/scenario_builder/nuplan_db/nuplan_scenario_builder.py:74}  === data root: /home/hujiangtao/nuplan/dataset/nuplan-v1.1/splits/mini
# 2023-08-28 10:37:05,933 INFO {/home/hujiangtao/github/nuplan-devkit/nuplan/planning/scenario_builder/nuplan_db/nuplan_scenario_builder.py:76}  === db_files: ['/home/hujiangtao/nuplan/dataset/nuplan-v1.1/splits/mini/2021.05.12.22.00.38_veh-35_01008_01518.db', '/home/hujiangtao/nuplan/dataset/nuplan-v1.1/splits/mini/2021.05.12.22.28.35_veh-35_00620_01164.db', '/home/hujiangtao/nuplan/dataset/nuplan-v1.1/splits/mini/2021.05.12.23.36.44_veh-35_00152_00504.db', '/home/hujiangtao/nuplan/dataset/nuplan-v1.1/splits/mini/2021.05.12.23.36.44_veh-35_01133_01535.db', '/home/hujiangtao/nuplan/dataset/nuplan-v1.1/splits/mini/2021.05.12.23.36.44_veh-35_02035_02387.db', '/home/hujiangtao/nuplan/dataset/nuplan-v1.1/splits/mini/2021.05.25.14.16.10_veh-35_01690_02183.db', '/home/hujiangtao/nuplan/dataset/nuplan-v1.1/splits/mini/2021.06.03.12.02.06_veh-35_00233_00609.db', '/home/hujiangtao/nuplan/dataset/nuplan-v1.1/splits/mini/2021.06.03.13.55.17_veh-35_00073_00426.db', '/home/hujiangtao/nuplan/dataset/nuplan-v1.1/splits/mini/2021.06.07.12.54.00_veh-35_01843_02314.db', '/home/hujiangtao/nuplan/dataset/nuplan-v1.1/splits/mini/2021.06.07.18.53.26_veh-26_00005_00427.db', '/home/hujiangtao/nuplan/dataset/nuplan-v1.1/splits/mini/2021.06.08.12.54.54_veh-26_04262_04732.db', '/home/hujiangtao/nuplan/dataset/nuplan-v1.1/splits/mini/2021.06.08.14.35.24_veh-26_02555_03004.db', '/home/hujiangtao/nuplan/dataset/nuplan-v1.1/splits/mini/2021.06.08.16.31.33_veh-38_01589_02072.db', '/home/hujiangtao/nuplan/dataset/nuplan-v1.1/splits/mini/2021.06.09.11.54.15_veh-12_04366_04810.db', '/home/hujiangtao/nuplan/dataset/nuplan-v1.1/splits/mini/2021.06.09.12.39.51_veh-26_01943_02303.db', '/home/hujiangtao/nuplan/dataset/nuplan-v1.1/splits/mini/2021.06.09.12.39.51_veh-26_05620_06003.db', '/home/hujiangtao/nuplan/dataset/nuplan-v1.1/splits/mini/2021.06.09.14.03.17_veh-12_02584_02970.db', '/home/hujiangtao/nuplan/dataset/nuplan-v1.1/splits/mini/2021.06.09.14.58.55_veh-35_01095_01484.db', '/home/hujiangtao/nuplan/dataset/nuplan-v1.1/splits/mini/2021.06.09.14.58.55_veh-35_01894_02311.db', '/home/hujiangtao/nuplan/dataset/nuplan-v1.1/splits/mini/2021.06.09.17.23.18_veh-38_00773_01140.db', '/home/hujiangtao/nuplan/dataset/nuplan-v1.1/splits/mini/2021.06.09.17.23.18_veh-38_02526_03027.db', '/home/hujiangtao/nuplan/dataset/nuplan-v1.1/splits/mini/2021.06.09.17.37.09_veh-12_00404_00864.db', '/home/hujiangtao/nuplan/dataset/nuplan-v1.1/splits/mini/2021.06.14.16.32.09_veh-35_05038_05402.db', '/home/hujiangtao/nuplan/dataset/nuplan-v1.1/splits/mini/2021.06.14.16.48.02_veh-12_04057_04438.db', '/home/hujiangtao/nuplan/dataset/nuplan-v1.1/splits/mini/2021.06.14.16.48.02_veh-12_04978_05337.db', '/home/hujiangtao/nuplan/dataset/nuplan-v1.1/splits/mini/2021.06.14.17.26.26_veh-38_04544_04920.db', '/home/hujiangtao/nuplan/dataset/nuplan-v1.1/splits/mini/2021.06.14.18.33.41_veh-35_03901_04264.db', '/home/hujiangtao/nuplan/dataset/nuplan-v1.1/splits/mini/2021.06.14.18.42.45_veh-12_03445_03902.db', '/home/hujiangtao/nuplan/dataset/nuplan-v1.1/splits/mini/2021.06.14.19.22.11_veh-38_01480_01860.db', '/home/hujiangtao/nuplan/dataset/nuplan-v1.1/splits/mini/2021.06.23.15.56.12_veh-16_00839_01285.db', '/home/hujiangtao/nuplan/dataset/nuplan-v1.1/splits/mini/2021.06.23.16.54.19_veh-35_00808_01256.db', '/home/hujiangtao/nuplan/dataset/nuplan-v1.1/splits/mini/2021.06.23.17.31.36_veh-16_00016_00377.db', '/home/hujiangtao/nuplan/dataset/nuplan-v1.1/splits/mini/2021.06.23.20.43.31_veh-16_03607_04007.db', '/home/hujiangtao/nuplan/dataset/nuplan-v1.1/splits/mini/2021.06.28.15.02.02_veh-38_02398_02848.db', '/home/hujiangtao/nuplan/dataset/nuplan-v1.1/splits/mini/2021.06.28.16.29.11_veh-38_01415_01821.db', '/home/hujiangtao/nuplan/dataset/nuplan-v1.1/splits/mini/2021.06.28.16.29.11_veh-38_03263_03766.db', '/home/hujiangtao/nuplan/dataset/nuplan-v1.1/splits/mini/2021.06.28.16.57.59_veh-26_00016_00484.db', '/home/hujiangtao/nuplan/dataset/nuplan-v1.1/splits/mini/2021.07.09.17.06.37_veh-35_00258_00748.db', '/ho ...
# 2023-08-28 10:37:05,933 INFO {/home/hujiangtao/github/nuplan-devkit/nuplan/planning/script/builders/scenario_building_builder.py:21}  Building AbstractScenarioBuilder...DONE!
# 2023-08-28 10:37:05,933 INFO {/home/hujiangtao/github/nuplan-devkit/nuplan/planning/script/builders/scenario_filter_builder.py:35}  Building ScenarioFilter...
# 2023-08-28 10:37:05,934 INFO {/home/hujiangtao/github/nuplan-devkit/nuplan/planning/script/builders/scenario_filter_builder.py:44}  Building ScenarioFilter...DONE!
# Ray objects: 100%|██████████████████████████████████████████████████| 32/32 [00:01<00:00, 20.29it/s]
# 2023-08-28 10:37:07,551 INFO {/home/hujiangtao/github/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:74}  Building metric engines...
# 2023-08-28 10:37:07,635 INFO {/home/hujiangtao/github/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:76}  Building metric engines...DONE
# 2023-08-28 10:37:07,635 INFO {/home/hujiangtao/github/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:80}  Building simulations from 31 scenarios...
# 2023-08-28 10:37:07,873 INFO {/home/hujiangtao/github/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:133}  Building simulations...DONE!
# 2023-08-28 10:37:07,873 INFO {/home/hujiangtao/github/nuplan-devkit/nuplan/planning/script/run_simulation.py:78}  Running simulation...
# 2023-08-28 10:37:07,873 INFO {/home/hujiangtao/github/nuplan-devkit/nuplan/planning/script/utils.py:138}  Executing runners...
# 2023-08-28 10:37:07,873 INFO {/home/hujiangtao/github/nuplan-devkit/nuplan/planning/simulation/runner/executor.py:82}  Starting 31 simulations using RayDistributed!
# Ray objects: 100%|██████████████████████████████████████████████████| 31/31 [00:05<00:00,  5.43it/s]
# 2023-08-28 10:37:13,599 INFO {/home/hujiangtao/github/nuplan-devkit/nuplan/planning/simulation/runner/executor.py:127}  Number of successful simulations: 31
# 2023-08-28 10:37:13,600 INFO {/home/hujiangtao/github/nuplan-devkit/nuplan/planning/simulation/runner/executor.py:128}  Number of failed simulations: 0
# 2023-08-28 10:37:13,600 INFO {/home/hujiangtao/github/nuplan-devkit/nuplan/planning/script/utils.py:147}  Finished executing runners!
# 2023-08-28 10:37:13,640 INFO {/home/hujiangtao/github/nuplan-devkit/nuplan/planning/script/utils.py:74}  Saved runner reports to /tmp/tutorial_nuplan_framework/simulation_simple_experiment/open_loop_boxes/2023.08.28.10.37.01/runner_report.parquet
# 2023-08-28 10:37:13,641 INFO {/home/hujiangtao/github/nuplan-devkit/nuplan/planning/simulation/main_callback/time_callback.py:27}  Simulation duration: 00:00:12 [HH:MM:SS]
# 2023-08-28 10:37:14,116 INFO {/home/hujiangtao/github/nuplan-devkit/nuplan/planning/simulation/main_callback/metric_file_callback.py:79}  Metric files integration: 00:00:00 [HH:MM:SS]
# 2023-08-28 10:37:14,184 INFO {/home/hujiangtao/github/nuplan-devkit/nuplan/planning/simulation/main_callback/metric_aggregator_callback.py:58}  Running metric aggregator: open_loop_boxes_weighted_average
# 2023-08-28 10:37:14,232 INFO {/home/hujiangtao/github/nuplan-devkit/nuplan/planning/simulation/main_callback/metric_aggregator_callback.py:69}  Metric aggregator: 00:00:00 [HH:MM:SS]
# Rendering histograms: 100%|███████████████████████████████████████████| 6/6 [00:01<00:00,  5.78it/s]
# 2023-08-28 10:37:16,159 INFO {/home/hujiangtao/github/nuplan-devkit/nuplan/planning/simulation/main_callback/metric_summary_callback.py:344}  Metric summary: 00:00:01 [HH:MM:SS]
# 2023-08-28 10:37:16,159 INFO {/home/hujiangtao/github/nuplan-devkit/nuplan/planning/script/run_simulation.py:80}  Finished running simulation!

# %%
print(simple_simulation_folder)
# Out:
# /tmp/tutorial_nuplan_framework/simulation_simple_experiment/open_loop_boxes/2023.08.28.10.37.01

# %% [markdown]
# ## Launch simulation (command line - alternative)

# %% [markdown]
# A simulation experiment can be launched alternatively with:
# ```
# $ python nuplan/planning/script/run_simulation.py \
#     +simulation=open_loop_boxes \
#     planner=simple_planner \
#     scenario_builder=nuplan_mini \
#     scenario_filter=all_scenarios \
#     scenario_filter.scenario_types="[near_multiple_vehicles, on_pickup_dropoff, starting_unprotected_cross_turn, high_magnitude_jerk]" \
#     scenario_filter.num_scenarios_per_type=10 \
# ```

# %% [markdown]
# ## Simulate a trained ML planner for comparison
#
# Using the same simulation settings as before, we can simulate a pretrained ML planner and compare the two.
#
# In this example you can take the model you trained earlier.

# %%
# Location of path with all simulation configs
CONFIG_PATH = '../nuplan/planning/script/config/simulation'
CONFIG_NAME = 'default_simulation'

# Get the checkpoint of the trained model
last_experiment = sorted(os.listdir(LOG_DIR))[-1]
train_experiment_dir = sorted(LOG_DIR.iterdir())[-1]
checkpoint = sorted((train_experiment_dir / 'checkpoints').iterdir())[-1]

MODEL_PATH = str(checkpoint).replace("=", "\=")

# Name of the experiment
EXPERIMENT = 'simulation_raster_experiment'

# Initialize configuration management system
hydra.core.global_hydra.GlobalHydra.instance().clear()  # reinitialize hydra if already initialized
hydra.initialize(config_path=CONFIG_PATH)

# Compose the configuration
cfg = hydra.compose(config_name=CONFIG_NAME, overrides=[
    f'experiment_name={EXPERIMENT}',
    f'group={SAVE_DIR}',
    'planner=ml_planner',
    'model=raster_model',
    'planner.ml_planner.model_config=${model}',  # hydra notation to select model config
    f'planner.ml_planner.checkpoint_path={MODEL_PATH}',  # this path can be replaced by the checkpoint of the model trained in the previous section
    f'+simulation={CHALLENGE}',
    *DATASET_PARAMS,
])

# Run the simulation loop
main_simulation(cfg)

# ML_planner simulation folder for visualization in nuBoard (next section)
ml_planner_simulation_folder = cfg.output_dir
# Out:
# Global seed set to 0
# 2023-08-28 11:42:12,111 INFO {/home/hujiangtao/github/nuplan-devkit/nuplan/planning/script/builders/main_callback_builder.py:20}  Building MultiMainCallback...
# 2023-08-28 11:42:12,111 INFO {/home/hujiangtao/github/nuplan-devkit/nuplan/planning/script/builders/main_callback_builder.py:20}  Building MultiMainCallback...
# 2023-08-28 11:42:12,252 INFO {/home/hujiangtao/github/nuplan-devkit/nuplan/planning/script/builders/main_callback_builder.py:35}  Building MultiMainCallback: 4...DONE!
# 2023-08-28 11:42:12,252 INFO {/home/hujiangtao/github/nuplan-devkit/nuplan/planning/script/builders/main_callback_builder.py:35}  Building MultiMainCallback: 4...DONE!
# 2023-08-28 11:42:13,419 INFO {/home/hujiangtao/github/nuplan-devkit/nuplan/planning/script/builders/worker_pool_builder.py:19}  Building WorkerPool...
# 2023-08-28 11:42:13,419 INFO {/home/hujiangtao/github/nuplan-devkit/nuplan/planning/script/builders/worker_pool_builder.py:19}  Building WorkerPool...
# 2023-08-28 11:42:13,430 WARNING {/home/hujiangtao/github/nuplan-devkit/nuplan/planning/utils/multithreading/worker_ray.py:135}  Ray is running, we will shut it down before starting again!
# 2023-08-28 11:42:13,430 WARNING {/home/hujiangtao/github/nuplan-devkit/nuplan/planning/utils/multithreading/worker_ray.py:135}  Ray is running, we will shut it down before starting again!
# 2023-08-28 11:42:16,744 INFO {/home/hujiangtao/github/nuplan-devkit/nuplan/planning/utils/multithreading/worker_ray.py:78}  Starting ray local!
# 2023-08-28 11:42:16,744 INFO {/home/hujiangtao/github/nuplan-devkit/nuplan/planning/utils/multithreading/worker_ray.py:78}  Starting ray local!
# 2023-08-28 11:42:26,268	INFO worker.py:1621 -- Started a local Ray instance.
# 2023-08-28 11:42:32,585 INFO {/home/hujiangtao/github/nuplan-devkit/nuplan/planning/utils/multithreading/worker_pool.py:101}  Worker: RayDistributed
# 2023-08-28 11:42:32,585 INFO {/home/hujiangtao/github/nuplan-devkit/nuplan/planning/utils/multithreading/worker_pool.py:101}  Worker: RayDistributed
# 2023-08-28 11:42:32,587 INFO {/home/hujiangtao/github/nuplan-devkit/nuplan/planning/utils/multithreading/worker_pool.py:102}  Number of nodes: 1
# Number of CPUs per node: 32
# Number of GPUs per node: 1
# Number of threads across all nodes: 32
# 2023-08-28 11:42:32,587 INFO {/home/hujiangtao/github/nuplan-devkit/nuplan/planning/utils/multithreading/worker_pool.py:102}  Number of nodes: 1
# Number of CPUs per node: 32
# Number of GPUs per node: 1
# Number of threads across all nodes: 32
# 2023-08-28 11:42:32,588 INFO {/home/hujiangtao/github/nuplan-devkit/nuplan/planning/script/builders/worker_pool_builder.py:27}  Building WorkerPool...DONE!
# 2023-08-28 11:42:32,588 INFO {/home/hujiangtao/github/nuplan-devkit/nuplan/planning/script/builders/worker_pool_builder.py:27}  Building WorkerPool...DONE!
# 2023-08-28 11:42:32,588 INFO {/home/hujiangtao/github/nuplan-devkit/nuplan/planning/script/builders/folder_builder.py:32}  Building experiment folders...
# 2023-08-28 11:42:32,588 INFO {/home/hujiangtao/github/nuplan-devkit/nuplan/planning/script/builders/folder_builder.py:32}  Building experiment folders...
# 2023-08-28 11:42:32,589 INFO {/home/hujiangtao/github/nuplan-devkit/nuplan/planning/script/builders/folder_builder.py:35}
#
# 	Folder where all results are stored: /tmp/tutorial_nuplan_framework/simulation_raster_experiment/open_loop_boxes/2023.08.28.11.42.12
#
# 2023-08-28 11:42:32,589 INFO {/home/hujiangtao/github/nuplan-devkit/nuplan/planning/script/builders/folder_builder.py:35}
#
# 	Folder where all results are stored: /tmp/tutorial_nuplan_framework/simulation_raster_experiment/open_loop_boxes/2023.08.28.11.42.12
#
# 2023-08-28 11:42:32,601 INFO {/home/hujiangtao/github/nuplan-devkit/nuplan/planning/script/builders/folder_builder.py:70}  Building experiment folders...DONE!
# 2023-08-28 11:42:32,601 INFO {/home/hujiangtao/github/nuplan-devkit/nuplan/planning/script/builders/folder_builder.py:70}  Building experiment folders...DONE!
# 
INFO {/home/hujiangtao/github/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2023-08-28 11:43:39,919 INFO {/home/hujiangtao/github/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2023-08-28 11:43:40,881 INFO {/home/hujiangtao/github/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2023-08-28 11:43:40,881 INFO {/home/hujiangtao/github/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# ...
# Rendering histograms: 100%|███████████████████████████████████████████| 6/6 [00:09<00:00,  1.56s/it]
# 2023-08-28 12:00:25,642 INFO {/home/hujiangtao/github/nuplan-devkit/nuplan/planning/simulation/main_callback/metric_summary_callback.py:344}  Metric summary: 00:00:19 [HH:MM:SS]
# 2023-08-28 12:00:25,642 INFO {/home/hujiangtao/github/nuplan-devkit/nuplan/planning/simulation/main_callback/metric_summary_callback.py:344}  Metric summary: 00:00:19 [HH:MM:SS]
# 2023-08-28 12:00:25,644 INFO {/home/hujiangtao/github/nuplan-devkit/nuplan/planning/script/run_simulation.py:80}  Finished running simulation!
# 2023-08-28 12:00:25,644 INFO {/home/hujiangtao/github/nuplan-devkit/nuplan/planning/script/run_simulation.py:80}  Finished running simulation!
# Ray objects:   0%|                                                                             | 0/31 [00:00<?, ?it/s](wrapped_fn pid=32670) /home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
# (wrapped_fn pid=32670)   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# (wrapped_fn pid=32668) /home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
# (wrapped_fn pid=32668)   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# (wrapped_fn pid=32662) /home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
# (wrapped_fn pid=32662)   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# (wrapped_fn pid=32657) /home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
# (wrapped_fn pid=32657)   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# (wrapped_fn pid=32652) /home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
# (wrapped_fn pid=32652)   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# (wrapped_fn pid=32675) /home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
# (wrapped_fn pid=32675)   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# (wrapped_fn pid=32650) /home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
# (wrapped_fn pid=32650)   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# (wrapped_fn pid=32654) /home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
# (wrapped_fn pid=32654)   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# (wrapped_fn pid=32665) /home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
# (wrapped_fn pid=32665)   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# (wrapped_fn pid=32671) /home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
# (wrapped_fn pid=32671)   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# (wrapped_fn pid=32674) /home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
# (wrapped_fn pid=32674)   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# (wrapped_fn pid=32661) /home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
# (wrapped_fn pid=32661)   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# (wrapped_fn pid=32672) /home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
# (wrapped_fn pid=32672)   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# (wrapped_fn pid=32655) /home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
# (wrapped_fn pid=32655)   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# (wrapped_fn pid=32660) /home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
# (wrapped_fn pid=32660)   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# (wrapped_fn pid=32649) /home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
# (wrapped_fn pid=32649)   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# (wrapped_fn pid=32666) /home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
# (wrapped_fn pid=32666)   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# (wrapped_fn pid=32663) /home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
# (wrapped_fn pid=32663)   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# (wrapped_fn pid=32648) /home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
# (wrapped_fn pid=32648)   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# (wrapped_fn pid=32656) /home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
# (wrapped_fn pid=32656)   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# (wrapped_fn pid=32647) /home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
# (wrapped_fn pid=32647)   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# (wrapped_fn pid=32651) /home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
# (wrapped_fn pid=32651)   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# (wrapped_fn pid=32658) /home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
# (wrapped_fn pid=32658)   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# (wrapped_fn pid=32673) /home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
# (wrapped_fn pid=32673)   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# (wrapped_fn pid=32676) /home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
# (wrapped_fn pid=32676)   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# (wrapped_fn pid=32678) /home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
# (wrapped_fn pid=32678)   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# (wrapped_fn pid=32659) /home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
# (wrapped_fn pid=32659)   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# (wrapped_fn pid=32664) /home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
# (wrapped_fn pid=32664)   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# (wrapped_fn pid=32677) /home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
# (wrapped_fn pid=32677)   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# (wrapped_fn pid=32669) /home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
# (wrapped_fn pid=32669)   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# (wrapped_fn pid=32653) /home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
# (wrapped_fn pid=32653)   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)

# %% [markdown]
# # Visualizing metrics and scenarios <a name="dashboard"></a>

# %% [markdown]
# ## nuBoard summary
#
# Having trained and simulated planners across various scenarios and driving behaviors, it's time to evaluate them:
# * quantitatively, through common and scenario dependent metrics
# * qualitatively, through visualization of scenario progression
#
# ### nuBoard tabs
# To achieve that, nuBoard has 3 core evaluation tabs:
# 1. Overview - Scalar metrics summary of common and scenario metrics across the following categories:
#     * Ego dynamics
#     * Traffic violations
#     * Expert imitation
#     * Planning & navigation
#     * Scenario performance
# 2. Histograms - Histograms over metric statistics for more a granular peek inside each metric focusing on:
#     * Metric statistics (e.g. min, max, p90)
# 3. Scenarios - Low-level scenario visualizations:
#     * Time-series progression of a specific metric across a scenario
#     * Top-down visualization of the scenario across time for comparing predicted vs. expert trajectories
#
# In addition, there is a main configuration tab for selecting different simulation files for comparing planners/experiments.
#
# <br />
#
# **NOTE**: nuBoard is under heavy developement, overall functionality and aesthetics do not represent the final product!

# %% [markdown]
# ## Prepare the nuBoard config

# %%
# Location of path with all nuBoard configs
CONFIG_PATH = '../nuplan/planning/script/config/nuboard'
CONFIG_NAME = 'default_nuboard'

# Initialize configuration management system
hydra.core.global_hydra.GlobalHydra.instance().clear()  # reinitialize hydra if already initialized
hydra.initialize(config_path=CONFIG_PATH)

# Compose the configuration
cfg = hydra.compose(config_name=CONFIG_NAME, overrides=[
    'scenario_builder=nuplan_mini',  # set the database (same as simulation) used to fetch data for visualization
    f'simulation_path={[simple_simulation_folder, ml_planner_simulation_folder]}',  # nuboard file path(s), if left empty the user can open the file inside nuBoard
])

# %% [markdown]
# ## Launch nuBoard (open in new tab - recommended)

# %%
from nuplan.planning.script.run_nuboard import main as main_nuboard

# Run nuBoard
main_nuboard(cfg)
# Out:
# INFO:bokeh.server.server:Starting Bokeh server version 2.4.3 (running on Tornado 6.3.3)
# WARNING:bokeh.server.util:Host wildcard '*' will allow connections originating from multiple (or possibly all) hostnames or IPs. Use non-wildcard values to restrict access explicitly
# INFO:bokeh.server.tornado:User authentication hooks NOT provided (default user enabled)
# 2023-08-28 13:29:47,874 INFO {/home/hujiangtao/github/nuplan-devkit/nuplan/planning/script/builders/scenario_building_builder.py:18}  Building AbstractScenarioBuilder...
# 2023-08-28 13:29:47,874 INFO {/home/hujiangtao/github/nuplan-devkit/nuplan/planning/script/builders/scenario_building_builder.py:18}  Building AbstractScenarioBuilder...
# 2023-08-28 13:29:47,948 INFO {/home/hujiangtao/github/nuplan-devkit/nuplan/planning/scenario_builder/nuplan_db/nuplan_scenario_builder.py:74}  === data root: /home/hujiangtao/nuplan/dataset/nuplan-v1.1/splits/mini
# 2023-08-28 13:29:47,948 INFO {/home/hujiangtao/github/nuplan-devkit/nuplan/planning/scenario_builder/nuplan_db/nuplan_scenario_builder.py:74}  === data root: /home/hujiangtao/nuplan/dataset/nuplan-v1.1/splits/mini
# 2023-08-28 13:29:47,955 INFO {/home/hujiangtao/github/nuplan-devkit/nuplan/planning/scenario_builder/nuplan_db/nuplan_scenario_builder.py:76}  === db_files: ['/home/hujiangtao/nuplan/dataset/nuplan-v1.1/splits/mini/2021.05.12.22.00.38_veh-35_01008_01518.db', '/home/hujiangtao/nuplan/dataset/nuplan-v1.1/splits/mini/2021.05.12.22.28.35_veh-35_00620_01164.db', '/home/hujiangtao/nuplan/dataset/nuplan-v1.1/splits/mini/2021.05.12.23.36.44_veh-35_00152_00504.db', '/home/hujiangtao/nuplan/dataset/nuplan-v1.1/splits/mini/2021.05.12.23.36.44_veh-35_01133_01535.db', '/home/hujiangtao/nuplan/dataset/nuplan-v1.1/splits/mini/2021.05.12.23.36.44_veh-35_02035_02387.db', '/home/hujiangtao/nuplan/dataset/nuplan-v1.1/splits/mini/2021.05.25.14.16.10_veh-35_01690_02183.db', '/home/hujiangtao/nuplan/dataset/nuplan-v1.1/splits/mini/2021.06.03.12.02.06_veh-35_00233_00609.db', '/home/hujiangtao/nuplan/dataset/nuplan-v1.1/splits/mini/2021.06.03.13.55.17_veh-35_00073_00426.db', '/home/hujiangtao/nuplan/dataset/nuplan-v1.1/splits/mini/2021.06.07.12.54.00_veh-35_01843_02314.db', '/home/hujiangtao/nuplan/dataset/nuplan-v1.1/splits/mini/2021.06.07.18.53.26_veh-26_00005_00427.db', '/home/hujiangtao/nuplan/dataset/nuplan-v1.1/splits/mini/2021.06.08.12.54.54_veh-26_04262_04732.db', '/home/hujiangtao/nuplan/dataset/nuplan-v1.1/splits/mini/2021.06.08.14.35.24_veh-26_02555_03004.db', '/home/hujiangtao/nuplan/dataset/nuplan-v1.1/splits/mini/2021.06.08.16.31.33_veh-38_01589_02072.db', '/home/hujiangtao/nuplan/dataset/nuplan-v1.1/splits/mini/2021.06.09.11.54.15_veh-12_04366_04810.db', '/home/hujiangtao/nuplan/dataset/nuplan-v1.1/splits/mini/2021.06.09.12.39.51_veh-26_01943_02303.db', '/home/hujiangtao/nuplan/dataset/nuplan-v1.1/splits/mini/2021.06.09.12.39.51_veh-26_05620_06003.db', '/home/hujiangtao/nuplan/dataset/nuplan-v1.1/splits/mini/2021.06.09.14.03.17_veh-12_02584_02970.db', '/home/hujiangtao/nuplan/dataset/nuplan-v1.1/splits/mini/2021.06.09.14.58.55_veh-35_01095_01484.db', '/home/hujiangtao/nuplan/dataset/nuplan-v1.1/splits/mini/2021.06.09.14.58.55_veh-35_01894_02311.db', '/home/hujiangtao/nuplan/dataset/nuplan-v1.1/splits/mini/2021.06.09.17.23.18_veh-38_00773_01140.db', '/home/hujiangtao/nuplan/dataset/nuplan-v1.1/splits/mini/2021.06.09.17.23.18_veh-38_02526_03027.db', '/home/hujiangtao/nuplan/dataset/nuplan-v1.1/splits/mini/2021.06.09.17.37.09_veh-12_00404_00864.db', '/home/hujiangtao/nuplan/dataset/nuplan-v1.1/splits/mini/2021.06.14.16.32.09_veh-35_05038_05402.db', '/home/hujiangtao/nuplan/dataset/nuplan-v1.1/splits/mini/2021.06.14.16.48.02_veh-12_04057_04438.db', '/home/hujiangtao/nuplan/dataset/nuplan-v1.1/splits/mini/2021.06.14.16.48.02_veh-12_04978_05337.db', '/home/hujiangtao/nuplan/dataset/nuplan-v1.1/splits/mini/2021.06.14.17.26.26_veh-38_04544_04920.db', '/home/hujiangtao/nuplan/dataset/nuplan-v1.1/splits/mini/2021.06.14.18.33.41_veh-35_03901_04264.db', '/home/hujiangtao/nuplan/dataset/nuplan-v1.1/splits/mini/2021.06.14.18.42.45_veh-12_03445_03902.db', '/home/hujiangtao/nuplan/dataset/nuplan-v1.1/splits/mini/2021.06.14.19.22.11_veh-38_01480_01860.db', '/home/hujiangtao/nuplan/dataset/nuplan-v1.1/splits/mini/2021.06.23.15.56.12_veh-16_00839_01285.db', '/home/hujiangtao/nuplan/dataset/nuplan-v1.1/splits/mini/2021.06.23.16.54.19_veh-35_00808_01256.db', '/home/hujiangtao/nuplan/dataset/nuplan-v1.1/splits/mini/2021.06.23.17.31.36_veh-16_00016_00377.db', '/home/hujiangtao/nuplan/dataset/nuplan-v1.1/splits/mini/2021.06.23.20.43.31_veh-16_03607_04007.db', '/home/hujiangtao/nuplan/dataset/nuplan-v1.1/splits/mini/2021.06.28.15.02.02_veh-38_02398_02848.db', '/home/hujiangtao/nuplan/dataset/nuplan-v1.1/splits/mini/2021.06.28.16.29.11_veh-38_01415_01821.db', '/home/hujiangtao/nuplan/dataset/nuplan-v1.1/splits/mini/2021.06.28.16.29.11_veh-38_03263_03766.db', '/home/hujiangtao/nuplan/dataset/nuplan-v1.1/splits/mini/2021.06.28.16.57.59_veh-26_00016_00484.db', '/home/hujiangtao/nuplan/dataset/nuplan-v1.1/splits/mini/2021.07.09.17.06.37_veh-35_00258_00748.db', '/ho ...
# 2023-08-28 13:29:47,955 INFO {/home/hujiangtao/github/nuplan-devkit/nuplan/planning/scenario_builder/nuplan_db/nuplan_scenario_builder.py:76}  === db_files: ['/home/hujiangtao/nuplan/dataset/nuplan-v1.1/splits/mini/2021.05.12.22
INFO {/home/hujiangtao/miniconda3/envs/nuplan3/lib/python3.9/site-packages/tornado/web.py:2344}  200 GET /resource/scripts/utils.js (::1) 3.90ms
# 2023-08-28 13:29:52,695 INFO {/home/hujiangtao/miniconda3/envs/nuplan3/lib/python3.9/site-packages/tornado/web.py:2344}  200 GET /resource/scripts/utils.js (::1) 3.90ms
# INFO:tornado.access:200 GET /resource/css/histogram.css (::1) 4.34ms
# INFO:tornado.access:200 GET /static/js/bokeh.min.js?v=3c61e952b808bb7e346ce828a565a5f23aaf7708d034fa9d0906403813355d45bb4e8d8b0b23a93f032c76831d4f0221846f28699c7f5147caa62e0d31668314 (::1) 19.51ms
# INFO:tornado.access:200 GET /static/js/bokeh-gl.min.js?v=e5df31fd9010eacff0aa72d315264604b5e34972ba445acea6fce98080eecf33acf2d2986126360faaa5852813cffa16f6f6f4889923318300f062497c02da4e (::1) 22.80ms
# INFO:tornado.access:200 GET /static/js/bokeh-widgets.min.js?v=8a1ff6f5aa0d967f4998d275803bbb111d928fd9f605ef9e1f30cfd021df0e77224ee3d13f83edb3a942f6e4ccc569ee5dd8951a8aa6cb600602463b90c65a87 (::1) 26.44ms
# INFO:tornado.access:200 GET /static/js/bokeh-tables.min.js?v=ae2903e57cf57f52819fdf4d938c648982b51c34f73b6e653a0f3bb3c8ab44f338505931ace43eafc1636e215492e2314acf54c54baffb47813b86b4923a7fe0 (::1) 25.84ms
# INFO:tornado.access:200 GET /static/js/bokeh-mathjax.min.js?v=176c36fdbcd8fc1019fc828101a2804081a35baf4018d7f2633cd263156b593aa73112f400112b662daa0590138b74851bc91f1f2a5fbf5416ee8c876c3e0d0c (::1) 11.91ms
# INFO:tornado.access:200 GET /resource/scripts/utils.js (::1) 3.90ms
# 2023-08-28 13:29:52,879 INFO {/home/hujiangtao/miniconda3/envs/nuplan3/lib/python3.9/site-packages/tornado/web.py:2344}  200 GET /resource/motional_logo.png (::1) 6.01ms
# 2023-08-28 13:29:52,879 INFO {/home/hujiangtao/miniconda3/envs/nuplan3/lib/python3.9/site-packages/tornado/web.py:2344}  200 GET /resource/motional_logo.png (::1) 6.01ms
# INFO:tornado.access:200 GET /resource/motional_logo.png (::1) 6.01ms
# INFO:bokeh.server.views.ws:WebSocket connection opened
# INFO:tornado.access:101 GET /ws (::1) 3.30ms
# INFO:bokeh.server.views.ws:ServerConnection created
# 2023-08-28 13:29:53,779 INFO {/home/hujiangtao/miniconda3/envs/nuplan3/lib/python3.9/site-packages/tornado/web.py:2344}  101 GET /ws (::1) 3.30ms
# 2023-08-28 13:29:53,779 INFO {/home/hujiangtao/miniconda3/envs/nuplan3/lib/python3.9/site-packages/tornado/web.py:2344}  101 GET /ws (::1) 3.30ms
# 2023-08-28 13:29:53,797 WARNING {/home/hujiangtao/miniconda3/envs/nuplan3/lib/python3.9/site-packages/tornado/web.py:2344}  404 GET /favicon.ico (::1) 3.01ms
# 2023-08-28 13:29:53,797 WARNING {/home/hujiangtao/miniconda3/envs/nuplan3/lib/python3.9/site-packages/tornado/web.py:2344}  404 GET /favicon.ico (::1) 3.01ms
# WARNING:tornado.access:404 GET /favicon.ico (::1) 3.01ms

# %% [markdown]
# ## Launch nuBoard (embedded within the notebook - alternative)

# %%
from bokeh.io import show, output_notebook
from nuplan.planning.script.run_nuboard import initialize_nuboard

# Make sure that the notebook working directory is "/notebooks" and that Jupyter was launched at the root of the repo
cfg.resource_prefix = '/notebooks/nuplan/planning/metrics/board/'  # pass CSS resources to the notebook

# Run the nuBoard
output_notebook()
nuboard = initialize_nuboard(cfg)
show(nuboard.main_page)

# %% [markdown]
# ## Launch nuBoard (command line - alternative)

# %% [markdown]
# nuBoard can be launched alternatively with:
# ```
# $ python nuplan/planning/script/run_nuboard.py
# ```
#
# Simulation files (.nuboard) can be selected under the configuration tab.
